# %% [markdown]
# # Dummy Notebook
#
# Doing something dumb.

# %%
"""Random number generator."""
import matplotlib.pyplot as plt
import random
import numpy as np

# Ensures random numbers generated are the same every run
np.random.seed(42)
random.seed(42)

new_number = np.random.randint(1, 10)
print(new_number)
# Out:
# 7
